# %% [markdown]
# # 1

# %% [markdown]
# Установка библиотек и подсоединение диска

# %%
# !pip install blocksnet ipykernel -q
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 71.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.8/277.8 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 48.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.1/255.1 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 46.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 55.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 46.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 33.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 59.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 58.2 MB/s eta 0:00:00
#   Building wheel for osm2geojson (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albucore 0.0.19 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.20 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# bigframes 1.29.0 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# chex 0.1.88 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# cudf-cu12 24.10.1 requires pyarrow<18.0.0a0,>=14.0.0, but you have pyarrow 12.0.0 which is incompatible.
# jax 0.4.33 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# jaxlib 0.4.33 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.4 requires matplotlib>=3.8.0, but you have matplotlib 3.7.1 which is incompatible.
# pylibcudf-cu12 24.10.1 requires pyarrow<18.0.0a0,>=14.0.0, but you have pyarrow 12.0.0 which is incompatible.
# pymc 5.19.1 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# scikit-image 0.25.0 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# xarray 2024.11.0 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.

# %%
import geopandas as gpd

# %%
pip install --upgrade pandera
# Out:
# Requirement already satisfied: pandera in /usr/local/lib/python3.10/dist-packages (0.20.2)
# Collecting pandera
#   Downloading pandera-0.22.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (24.2)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (2.2.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from pandera) (2.10.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.10/dist-packages (from pandera) (4.4.1)
# Requirement already satisfied: typing_inspect>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pandera) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pandera) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pandera) (2024.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing_inspect>=0.6.0->pandera) (1.0.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from typing_inspect>=0.6.0->pandera) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->pandera) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic->pandera) (2.27.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pandera) (1.17.0)
# Downloading pandera-0.22.0-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 14.4 MB/s eta 0:00:00
# Installing collected packages: pandera
#   Attempting uninstall: pandera
#     Found existing installation: pandera 0.20.2
#     Uninstalling pandera-0.20.2:
#       Successfully uninstalled pandera-0.20.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# blocksnet 0.0.12 requires pandera==0.20.2, but you have pandera 0.22.0 which is incompatible.
# Successfully installed pandera-0.22.0

# %%
import pandas as pd

# %%
import osmnx as ox

# %%
from google.colab import drive
import os

# Подключение к Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Загрузка данных

# %%
boundary = ox.geocode_to_gdf('Приозерск')

# %%
boundary.plot()
# Out:
# <Axes: >

# %%
tags = {
    'roads': {
      "highway": ["construction","crossing","living_street","motorway","motorway_link","motorway_junction","pedestrian","primary","primary_link","raceway","residential","road","secondary","secondary_link","services","tertiary","tertiary_link","track","trunk","trunk_link","turning_circle","turning_loop","unclassified",],
      "service": ["living_street", "emergency_access"]
    },
    'railways': {
      "railway": "rail"
    },
    'water': {
      'riverbank':True,
      'reservoir':True,
      'basin':True,
      'dock':True,
      'canal':True,
      'pond':True,
      'natural':['water','bay'],
      'waterway':['river','canal','ditch'],
      'landuse':'basin',
      'water': 'lake'
    }
}

# %% [markdown]
# Чтобы оно опять о послезавтра не загружалось, после загрузки сохраняем в файлы. Если это первый запуск, то убрать #

# %%
# water = ox.features_from_polygon(boundary.unary_union, tags['water'])
roads = ox.features_from_polygon(boundary.unary_union, tags['roads'])

railways = ox.features_from_polygon(boundary.unary_union, tags['railways'])

# %%
roads = roads[roads.geometry.geom_type.isin(["LineString", "MultiLineString"])]
#water = water[water.geometry.geom_type.isin(["LineString", "MultiLineString"])]
railways = railways[railways.geometry.geom_type.isin(["LineString", "MultiLineString"])]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
roads.to_file("roads.geojson", driver='GeoJSON')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[303843792, 7608359012, 12294707715, 824623309, 11970801235, 11970801328, 824623318, 11970801190, 11970801245, 11970801243, 11970801241, 7952494995, 824623366, 11970801207, 1231558520, 1231558566, 303843815, 11687336732, 824623381, 11687336733, 1966781723, 11687336605, 12294707706, 1966781722, 11687336609, 11687336610, 1035552482, 11687336883, 1035550465, 11882158306, 11687336781, 11882158311, 1035556647, 11882158389, 11687336946, 11677410570, 1035580000, 11677410569, 11677377168, 6442561618, 11687336806, 11687336809, 11687336948, 303843826, 1231503553, 1231503585, 1231503655, 1231503687, 12294707705, 1231503775, 1379083635, 5279486327, 5824583285, 252308078]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=

# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[264001458, 6586591699, 1977824685, 1977824669, 6586578379, 1977824661, 1977824659, 6586578380, 1977824658, 6586578381, 1977824660, 1977824675, 1977824717]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[3097589731, 3097589730, 3097589525, 3097589524, 3097589522, 3097589520, 3097589518, 1834653492]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[1044067205, 1044067284]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[1044066871, 6586578359, 6586578360, 6586578361, 6586578362, 6586578363, 9325751585, 9325751584, 6586578364, 6586578354]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[1506549877, 1506549850]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[6586578370, 6586578369]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[6586578371, 1506549872]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[1506549854, 6586578372, 6586578373, 6586578374, 6586578375, 6586578376, 6586578377, 1977824685]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[6586578378, 6586578377]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[6586578382, 6586578383, 6586578384, 6586591685, 6586591686, 6586591687, 6586591688, 1977824661]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[6586591689, 6586591690, 6586591691, 6586591692, 6586591693, 1977824669]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[6586591692, 6586591694]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[6586591695, 6586591696, 6586591693]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[6586578357, 6586591697, 6586591696]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[6586591697, 6586591698, 6586591699]
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='nodes', value=[1693716460, 2012486875]

# %%
roads = gpd.read_file("/content/roads.geojson")
water = gpd.read_file("/content/water.geojson")
railways = gpd.read_file("/content/railways.geojson")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # 2

# %%
roads2 = gpd.read_file('/content/drive/MyDrive/Priozersk_base_data/выходные дынные/k3komm/AUTOMATED_PLANNING_175789_automated_planning_suggestion_1_layers.geojson')

# %%
roads2.plot()
# Out:
# <Axes: >
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()

# %%
roads3 = roads2[roads2.geometry.geom_type.isin(["LineString", "MultiLineString", "LinearRing"])]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
roads3.plot()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: >

# %%
roads4 = roads3.explode(index_parts=True).reset_index(drop=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(roads4.geom_type.unique())
# Out:
# ['LineString']
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
roads4.to_file("roads1.geojson", driver='GeoJSON')
# Out:
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='parkingEntrance', value=False
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='allowDeadEnd', value=False
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='allowDeadEnd', value=True
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='parkingEntrance', value=True

# %%
territory = gpd.read_file('/content/border.geojson')

# Убедитесь, что оба GeoDataFrame имеют одинаковую систему координат
if roads.crs != territory.crs:
    roads = roads.to_crs(territory.crs)

# Выполняем операцию difference
roads5 = gpd.overlay(roads4, territory, how='difference')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
territory.plot()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: >

# %%
roads5 = roads4.dropna(axis=1, how='all')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
roads6 = roads5.clip(territory)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
roads6.plot()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: >

# %%
roads7 = roads6[
    (roads6['highway'].isin(['primary', 'residential', 'secondary']))
]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
roads7.plot()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: >

# %%
# Так как дальше модель со всеми данными не работает, то выгружаю это файлом для дальнейшей работы в QGis
roads7.to_file("roads7.geojson", driver='GeoJSON')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='parkingEntrance', value=False
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='allowDeadEnd', value=True
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='allowDeadEnd', value=False

# %%
local_crs = boundary.estimate_utm_crs()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
boundaries = boundary.reset_index()[['geometry']].to_crs(local_crs)
water = water.reset_index()[['geometry']].to_crs(local_crs)
roads = roads.reset_index()[['geometry']].to_crs(local_crs)
railways = railways.reset_index()[['geometry']].to_crs(local_crs)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
roads8 = roads7.dissolve()

# %%
# Так как дальше модель со всеми данными не работает, то выгружаю это файлом для дальнейшей работы в QGis
roads8.to_file("roads8.geojson", driver='GeoJSON')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='parkingEntrance', value=False
# WARNING:fiona.ogrext:Skipping field because of invalid value: key='allowDeadEnd', value=True

# %%
print(f"Roads count: {len(roads8)}")
# Out:
# Roads count: 1
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#roads11.plot()

# %%
#roads = roads11.explode(index_parts=True).reset_index(drop=True)

# %%
#print(f"Roads count: {len(roads)}")

# %%
# roads7 = roads7.reset_index()[['geometry']].to_crs(local_crs)

# %%
#print(roads.crs)
#print(roads7.crs)

# %%
#roads = pd.concat([roads,roads7], ignore_index=True)
# Это присоединение наших данных к оригинальным...

# %%
#roads

# %%
#print(roads.geom_type.unique())

# %%
#print(roads7.geom_type.unique())

# %%
# Функция для очистки GeoDataFrame
#def clean_geometries(gdf):
    # Удаление некорректных геометрий
 #   gdf = gdf[gdf.geometry.is_valid]

    # Удаление пустых геометрий
  #  gdf = gdf[~gdf.geometry.is_empty]

    # Удаление NaN значений
   # gdf = gdf[gdf.geometry.notna()]

    #return gdf

# Применение очистки к данным
#boundaries = clean_geometries(boundaries)
#water = clean_geometries(water)
#roads = clean_geometries(roads)
#railways = clean_geometries(railways)

# %%
#if boundaries.geometry.isna().any():
 #   print("Boundaries contain NaN values")
#if water.geometry.isna().any():
 #   print("Water contains NaN values")
#if roads.geometry.isna().any():
 #   print("Roads contain NaN values")
#if railways.geometry.isna().any():
 #   print("Railways contain NaN values")

# %%
#print(f"Boundaries count: {len(boundaries)}")
#print(f"Water count: {len(water)}")
#print(f"Roads count: {len(roads)}")
#print(f"Railways count: {len(railways)}")

# %%
#roads.plot()

# %%
#overlaps = roads.geometry.apply(lambda geom: roads.geometry.intersects(geom).sum() > 1)
#if overlaps.any():
 #   print("Некоторые геометрии пересекаются.")

# %%
#import numpy as np

# Проверка на NaN
#if roads['geometry'].isnull().any():
 #   print("Есть NaN значения в геометриях")

# Проверка на Inf
#if (roads['geometry'].apply(lambda geom: geom.is_empty or geom.is_valid).any() == False):
  #  print("Есть некорректные геометрии")

# %%
#roads.to_file("roadsw.geojson", driver='GeoJSON')

# %%
#roads = gpd.read_file("/content/roadswr.geojson")

# %%
#roads['geometry'] = roads['geometry'].buffer(0)

# %%
#invalid_geometries = roads[~roads.geometry.is_valid]
#print(invalid_geometries)

# %%
#roads = roads[~roads.geometry.is_empty]

# %%
#empty_geometries = roads[roads.geometry.is_empty]
#print(empty_geometries)

# %%
# print(roads.dtypes)

# %%
# roads = roads.reset_index()[['geometry']].to_crs(local_crs)

# %%
# roads.to_file("roads1.geojson", driver='GeoJSON')

# %%
from blocksnet import BlocksGenerator

bg = BlocksGenerator(boundaries, roads, railways, water)
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# 				element.innerHTML = 'function NetworKit_pageEmbed(id) { var i, j; var elements; elements = document.getElementById(id).getElementsByClassName("Plot"); for (i=0; i<elements.length; i++) { elements[i].id = id + "_Plot_" + i; var data = elements[i].getAttribute("data-image").split("|"); elements[i].removeAttribute("data-image"); var content = "<div class=\\"Image\\" id=\\"" + elements[i].id + "_Image\\" />"; elements[i].innerHTML = content; elements[i].setAttribute("data-image-index", 0); elements[i].setAttribute("data-image-length", data.length); for (j=0; j<data.length; j++) { elements[i].setAttribute("data-image-" + j, data[j]); } NetworKit_plotUpdate(elements[i]); elements[i].onclick = function (e) { NetworKit_overlayShow((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("HeatCell"); for (i=0; i<elements.length; i++) { var data = parseFloat(elements[i].getAttribute("data-heat")); var color = "#00FF00"; if (data <= 1 && data > 0) { color = "hsla(0, 100%, 75%, " + (data) + ")"; } else if (data <= 0 && data >= -1) { color = "hsla(240, 100%, 75%, " + (-data) + ")"; } elements[i].style.backgroundColor = color; } elements = document.getElementById(id).getElementsByClassName("Details"); for (i=0; i<elements.length; i++) { elements[i].setAttribute("data-title", "-"); NetworKit_toggleDetails(elements[i]); elements[i].onclick = function (e) { NetworKit_toggleDetails((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("MathValue"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "nan") { elements[i].parentNode.innerHTML = "" } } elements = document.getElementById(id).getElementsByClassName("SubCategory"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } elements = document.getElementById(id).getElementsByClassName("Category"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } var isFirefox = false; try { isFirefox = typeof InstallTrigger !== "undefined"; } catch (e) {} if (!isFirefox) { alert("Currently the function\'s output is only fully supported by Firefox."); } } function NetworKit_plotUpdate(source) { var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById(source.id + "_Image"); image.style.backgroundImage = "url(" + data + ")"; } function NetworKit_showElement(id, show) { var element = document.getElementById(id); element.style.display = (show) ? "block" : "none"; } function NetworKit_overlayShow(source) { NetworKit_overlayUpdate(source); NetworKit_showElement("NetworKit_Overlay", true); } function NetworKit_overlayUpdate(source) { document.getElementById("NetworKit_Overlay_Title").innerHTML = source.title; var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById("NetworKit_Overlay_Image"); image.setAttribute("data-id", source.id); image.style.backgroundImage = "url(" + data + ")"; var link = document.getElementById("NetworKit_Overlay_Toolbar_Bottom_Save"); link.href = data; link.download = source.title + ".svg"; } function NetworKit_overlayImageShift(delta) { var image = document.getElementById("NetworKit_Overlay_Image"); var source = document.getElementById(image.getAttribute("data-id")); var index = parseInt(source.getAttribute("data-image-index")); var length = parseInt(source.getAttribute("data-image-length")); var index = (index+delta) % length; if (index < 0) { index = length + index; } source.setAttribute("data-image-index", index); NetworKit_overlayUpdate(source); } function NetworKit_toggleDetails(source) { var childs = source.children; var show = false; if (source.getAttribute("data-title") == "-") { ...
# 				element.setAttribute('id', 'NetworKit_script');
# 				document.head.appendChild(element);
# 			}
#
#
# 			{
# 				var element = document.getElementById('NetworKit_style');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('style');
# 				element.type = 'text/css';
# 				element.innerHTML = '.NetworKit_Page { font-family: Arial, Helvetica, sans-serif; font-size: 14px; } .NetworKit_Page .Value:before { font-family: Arial, Helvetica, sans-serif; font-size: 1.05em; content: attr(data-title) ":"; margin-left: -2.5em; padding-right: 0.5em; } .NetworKit_Page .Details .Value:before { display: block; } .NetworKit_Page .Value { font-family: monospace; white-space: pre; padding-left: 2.5em; white-space: -moz-pre-wrap !important; white-space: -pre-wrap; white-space: -o-pre-wrap; white-space: pre-wrap; word-wrap: break-word; tab-size: 4; -moz-tab-size: 4; } .NetworKit_Page .Category { clear: both; padding-left: 1em; margin-bottom: 1.5em; } .NetworKit_Page .Category:before { content: attr(data-title); font-size: 1.75em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory { margin-bottom: 1.5em; padding-left: 1em; } .NetworKit_Page .SubCategory:before { font-size: 1.6em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory[data-title]:before { content: attr(data-title); } .NetworKit_Page .Block { display: block; } .NetworKit_Page .Block:after { content: "."; visibility: hidden; display: block; height: 0; clear: both; } .NetworKit_Page .Block .Thumbnail_Overview, .NetworKit_Page .Block .Thumbnail_ScatterPlot { width: 260px; float: left; } .NetworKit_Page .Block .Thumbnail_Overview img, .NetworKit_Page .Block .Thumbnail_ScatterPlot img { width: 260px; } .NetworKit_Page .Block .Thumbnail_Overview:before, .NetworKit_Page .Block .Thumbnail_ScatterPlot:before { display: block; text-align: center; font-weight: bold; } .NetworKit_Page .Block .Thumbnail_Overview:before { content: attr(data-title); } .NetworKit_Page .HeatCell { font-family: "Courier New", Courier, monospace; cursor: pointer; } .NetworKit_Page .HeatCell, .NetworKit_Page .HeatCellName { display: inline; padding: 0.1em; margin-right: 2px; background-color: #FFFFFF } .NetworKit_Page .HeatCellName { margin-left: 0.25em; } .NetworKit_Page .HeatCell:before { content: attr(data-heat); display: inline-block; color: #000000; width: 4em; text-align: center; } .NetworKit_Page .Measure { clear: both; } .NetworKit_Page .Measure .Details { cursor: pointer; } .NetworKit_Page .Measure .Details:before { content: "[" attr(data-title) "]"; display: block; } .NetworKit_Page .Measure .Details .Value { border-left: 1px dotted black; margin-left: 0.4em; padding-left: 3.5em; pointer-events: none; } .NetworKit_Page .Measure .Details .Spacer:before { content: "."; opacity: 0.0; pointer-events: none; } .NetworKit_Page .Measure .Plot { width: 440px; height: 440px; cursor: pointer; float: left; margin-left: -0.9em; margin-right: 20px; } .NetworKit_Page .Measure .Plot .Image { background-repeat: no-repeat; background-position: center center; background-size: contain; height: 100%; pointer-events: none; } .NetworKit_Page .Measure .Stat { width: 500px; float: left; } .NetworKit_Page .Measure .Stat .Group { padding-left: 1.25em; margin-bottom: 0.75em; } .NetworKit_Page .Measure .Stat .Group .Title { font-size: 1.1em; display: block; margin-bottom: 0.3em; margin-left: -0.75em;
# 2024-12-24 12:41:35.755 | INFO     | blocksnet.preprocessing.blocks_generator:__init__:99 - Check boundaries schema
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# /usr/local/lib/python3.10/dist-packages/pyspark/pandas/__init__.py:50: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# 2024-12-24 12:41:37.731 | INFO     | blocksnet.preprocessing.blocks_generator:__init__:103 - Check roads schema
# 2024-12-24 12:41:37.741 | INFO     | blocksnet.preprocessing.blocks_generator:__init__:109 - Check railways schema
# 2024-12-24 12:41:37.750 | INFO     | blocksnet.preprocessing.blocks_generator:__init__:115 - Check water schema
# 2024-12-24 12:41:37.757 | INFO     | blocksnet.preprocessing.blocks_generator:__init__:124 - Exclude water objects

# %%
blocks = bg.run()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2024-12-24 12:41:42.405 | INFO     | blocksnet.preprocessing.blocks_generator:run:161 - Generating blocks
# 2024-12-24 12:41:42.435 | INFO     | blocksnet.preprocessing.blocks_generator:run:170 - Setting up enclosures
# 2024-12-24 12:41:43.584 | INFO     | blocksnet.preprocessing.blocks_generator:run:174 - Filling holes
# 2024-12-24 12:41:43.616 | INFO     | blocksnet.preprocessing.blocks_generator:run:178 - Dropping overlapping blocks
# 2024-12-24 12:41:43.678 | INFO     | blocksnet.preprocessing.blocks_generator:run:192 - Calculating blocks area
# 2024-12-24 12:41:43.688 | INFO     | blocksnet.preprocessing.blocks_generator:run:199 - Blocks generated

# %% [markdown]
# С помощью библиотеки mapclassify мы можем выводить геометрии на карту через `.explore()`.

# %%
# !pip install mapclassify -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 4.7 MB/s eta 0:00:00

# %%
blocks.to_file("blocks.geojson", driver='GeoJSON')

# %%
print(blocks.geom_type.unique())
# Out:
# ['Polygon']
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
blocks
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
#                                               geometry
# 0    POLYGON ((346307.484 6771042.220, 346270.260 6...
# 1    POLYGON ((346073.443 6770898.652, 346259.780 6...
# 2    POLYGON ((346073.443 6770898.652, 346024.616 6...
# 3    POLYGON ((345896.310 6770788.058, 345938.014 6...
# 4    POLYGON ((345896.310 6770788.058, 345887.934 6...
# ..                                                 ...
# 242  POLYGON ((343625.747 6770130.054, 343573.762 6...
# 243  POLYGON ((343573.762 6770163.437, 343529.946 6...
# 244  POLYGON ((343529.946 6770192.054, 343494.932 6...
# 245  POLYGON ((343409.830 6770318.092, 343270.800 6...
# 246  POLYGON ((343158.304 6770527.901, 343202.113 6...
#
# [247 rows x 1 columns]

# %%
blocks.explore()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d675d8b6c65218235c7fb38e41b9d592 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d675d8b6c65218235c7fb38e41b9d592&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d675d8b6c65218235c7fb38e41b9d592 = L.map(
#                 &quot;map_d675d8b6c65218235c7fb38e41b9d592&quot;,
#                 {
#                     center: [61.032880399999996, 30.148203100000003],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d675d8b6c65218235c7fb38e41b9d592);
#
#
#
#
#
#             var tile_layer_929c7a4f3aca7a5868cd8fe6e644538b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_929c7a4f3aca7a5868cd8fe6e644538b.addTo(map_d675d8b6c65218235c7fb38e41b9d592);
#
#
#             map_d675d8b6c65218235c7fb38e41b9d592.fitBounds(
#                 [[60.9994246, 30.086310200000003], [61.0663362, 30.210096]],
#                 {}
#             );
#
#
#         function geo_json_ac159edfc778701561608f27ecef1af1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_ac159edfc778701561608f27ecef1af1_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ac159edfc778701561608f27ecef1af1_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_ac159edfc778701561608f27ecef1af1_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_ac159edfc778701561608f27ecef1af1_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_ac159edfc778701561608f27ecef1af1.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_ac159edfc778701561608f27ecef1af1_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_ac159edfc778701561608f27ecef1af1 = L.geoJson(null, {
#                 onEachFeature: geo_json_ac159edfc778701561608f27ecef1af1_onEachFeature,
#
#                 style: geo_json_ac159edfc778701561608f27ecef1af1_styler,
#                 pointToLayer: geo_json_ac159edfc778701561608f27ecef1af1_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_ac159edfc778701561608f27ecef1af1_add (data) {
#             geo_json_ac159edfc778701561608f27ecef1af1
#                 .addData(data);
#         }
#             geo_json_ac159edfc778701561608f27ecef1af1_add({&quot;bbox&quot;: [30.086310200000003, 60.9994246, 30.210096, 61.0663362], &quot;features&quot;: [{&quot;bbox&quot;: [30.148452999999996, 61.04273560000001, 30.1537903, 61.044908400000004], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.1537903, 61.04411430000001], [30.153120100000002, 61.043897499999986], [30.1529315, 61.04383560000001], [30.149578099999996, 61.04273560000001], [30.1495071, 61.042788899999984], [30.1490083, 61.04316299999994], [30.148452999999996, 61.04354329999997], [30.1491127, 61.04378109999997], [30.150078300000004, 61.044087499999996], [30.150457300000003, 61.044209800000004], [30.1509151, 61.0443576], [30.151280100000005, 61.04446160000001], [30.1516447, 61.044565399999996], [30.152149,

# %%
buildings = ox.features_from_polygon(boundaries.to_crs(4326).unary_union, {'building': True})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
buildings
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                         amenity brand contact:phone contact:website  \
# element_type osmid
# node         6398486913     NaN   NaN           NaN             NaN
#              6415977015     NaN   NaN           NaN             NaN
#              6415977821     NaN   NaN           NaN             NaN
#              6415978048     NaN   NaN           NaN             NaN
#              6415978050     NaN   NaN           NaN             NaN
# ...                         ...   ...           ...             ...
# relation     17702428       NaN   NaN           NaN             NaN
#              17702431       NaN   NaN           NaN             NaN
#              17952163       NaN   NaN           NaN             NaN
#              17952168       NaN   NaN           NaN             NaN
#              18431277       NaN   NaN           NaN             NaN
#
#                                                              opening_hours  \
# element_type osmid
# node         6398486913  Mo, Fr 09:00-12:00; Tu, Th 09:00-12:00, 13:00-...
#              6415977015                                                NaN
#              6415977821                                                NaN
#              6415978048                                                NaN
#              6415978050                                                NaN
# ...                                                                    ...
# relation     17702428                                                  NaN
#              17702431                                                  NaN
#              17952163                                                  NaN
#              17952168                                                  NaN
#              18431277                                                  NaN
#
#                         operator  \
# element_type osmid
# node         6398486913      NaN
#              6415977015      NaN
#              6415977821      NaN
#              6415978048      NaN
#              6415978050      NaN
# ...                          ...
# relation     17702428        NaN
#              17702431        NaN
#              17952163        NaN
#              17952168        NaN
#              18431277        NaN
#
#                                                                   geometry  \
# element_type osmid
# node         6398486913                          POINT (30.11746 61.03869)
#              6415977015                          POINT (30.11986 61.04176)
#              6415977821                          POINT (30.11814 61.04172)
#              6415978048                          POINT (30.11728 61.04159)
#              6415978050                          POINT (30.11680 61.04155)
# ...                                                                    ...
# relation     17702428    POLYGON ((30.13727 61.04159, 30.13712 61.04182...
#              17702431    POLYGON ((30.13994 61.04238, 30.13992 61.04241...
#              17952163    POLYGON ((30.11237 61.03798, 30.11231 61.03797...
#              17952168    POLYGON ((30.10203 61.03626, 30.10186 61.03632...
#              18431277    POLYGON ((30.11498 61.05219, 30.11493 61.05225...
#
#                          ref  name shop  ... name:fi location  \
# element_type osmid                       ...
# node         6398486913  NaN  ЕИРЦ  NaN  ...     NaN      NaN
#              6415977015  NaN   NaN  NaN  ...     NaN      NaN
#              6415977821  NaN   NaN  NaN  ...     NaN      NaN
#              6415978048  NaN   NaN  NaN  ...     NaN      NaN
#              6415978050  NaN   NaN  NaN  ...     NaN      NaN
# ...                      ...   ...  ...  ...     ...      ...
# relation     17702428    NaN   NaN  NaN  ...     NaN      NaN
#              17702431    NaN   NaN  NaN  ...     NaN      NaN
#              17952163    NaN   NaN  NaN  ...     NaN      NaN
#              17952168    NaN   NaN  NaN  ...     NaN      NaN
#              18431277    NaN   NaN  NaN  ...     NaN      NaN
#
#                         internet_access:fee outdoor_seating addr:town  \
# element_type osmid
# node         6398486913                 NaN             NaN       NaN
#              6415977015                 NaN             NaN       NaN
#              6415977821                 NaN             NaN       NaN
#              6415978048                 NaN             NaN       NaN
#              6415978050                 NaN             NaN       NaN
# ...                                     ...             ...       ...
# relation     17702428                   NaN             NaN       NaN
#              17702431                   NaN             NaN       NaN
#              17952163                   NaN             NaN       NaN
#              17952168                   NaN             NaN       NaN
#              18431277                   NaN             NaN       NaN
#
#                         power_supply  \
# element_type osmid
# node         6398486913          NaN
#              6415977015          NaN
#              6415977821          NaN
#              6415978048          NaN
#              6415978050          NaN
# ...                              ...
# relation     17702428            NaN
#              17702431            NaN
#              17952163            NaN
#              17952168            NaN
#              18431277            NaN
#
#                                                                     ways  \
# element_type osmid
# node         6398486913                                              NaN
#              6415977015                                              NaN
#              6415977821                                              NaN
#              6415978048                                              NaN
#              6415978050                                              NaN
# ...                                                                  ...
# relation     17702428                             [107108533, 232215690]
#              17702431                             [232215691, 107108541]
#              17952163    [1308890409, 1308890410, 327372898, 1308890408]
#              17952168                            [108069713, 1308890431]
#              18431277     [1343073382, 144268006, 1343073380, 805239365]
#
#                                  type wikidata wikipedia
# element_type osmid
# node         6398486913           NaN      NaN       NaN
#              6415977015           NaN      NaN       NaN
#              6415977821           NaN      NaN       NaN
#              6415978048           NaN      NaN       NaN
#              6415978050           NaN      NaN       NaN
# ...                               ...      ...       ...
# relation     17702428    multipolygon      NaN       NaN
#              17702431    multipolygon      NaN       NaN
#              17952163    multipolygon      NaN       NaN
#              17952168    multipolygon      NaN       NaN
#              18431277    multipolygon      NaN       NaN
#
# [3002 rows x 113 columns]

# %%
# buildings = buildings.to_crs(local_crs).reset_index()[['geometry']]
buildings.geometry = buildings.representative_point()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print("Индекс blocks:")
print(blocks.index)

print("Индекс buildings:")
print(buildings.index)
# Out:
# Индекс blocks:
# RangeIndex(start=0, stop=247, step=1)
# Индекс buildings:
# MultiIndex([(    'node', 6398486913),
#             (    'node', 6415977015),
#             (    'node', 6415977821),
#             (    'node', 6415978048),
#             (    'node', 6415978050),
#             (    'node', 6415978340),
#             (    'node', 6415980893),
#             (     'way',   39863011),
#             (     'way',   58124707),
#             (     'way',   89219718),
#             ...
#             ('relation',   17299709),
#             ('relation',   17299713),
#             ('relation',   17563052),
#             ('relation',   17563056),
#             ('relation',   17563059),
#             ('relation',   17702428),
#             ('relation',   17702431),
#             ('relation',   17952163),
#             ('relation',   17952168),
#             ('relation',   18431277)],
#            names=['element_type', 'osmid'], length=3002)

# %%
blocks = blocks.reset_index(drop=True)
buildings = buildings.reset_index(drop=True)
print("Уникальность индексов в blocks:", blocks.index.is_unique)
print("Уникальность индексов в buildings:", buildings.index.is_unique)
# Out:
# Уникальность индексов в blocks: True
# Уникальность индексов в buildings: True

# %%
if blocks.crs != buildings.crs:
    print("CRS не совпадают. Приведение buildings к CRS blocks...")
    buildings = buildings.to_crs(blocks.crs)
print("Первые строки blocks:")
print(blocks.head())

print("Первые строки buildings:")
print(buildings.head())
# Out:
# CRS не совпадают. Приведение buildings к CRS blocks...
# Первые строки blocks:
#                                             geometry
# 0  POLYGON ((346307.484 6771042.220, 346270.260 6...
# 1  POLYGON ((346073.443 6770898.652, 346259.780 6...
# 2  POLYGON ((346073.443 6770898.652, 346024.616 6...
# 3  POLYGON ((345896.310 6770788.058, 345938.014 6...
# 4  POLYGON ((345896.310 6770788.058, 345887.934 6...
# Первые строки buildings:
#   amenity brand contact:phone contact:website  \
# 0     NaN   NaN           NaN             NaN
# 1     NaN   NaN           NaN             NaN
# 2     NaN   NaN           NaN             NaN
# 3     NaN   NaN           NaN             NaN
# 4     NaN   NaN           NaN             NaN
#
#                                        opening_hours operator  \
# 0  Mo, Fr 09:00-12:00; Tu, Th 09:00-12:00, 13:00-...      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NaN
# 3                                                NaN      NaN
# 4                                                NaN      NaN
#
#                          geometry  ref  name shop  ... name:fi location  \
# 0  POINT (344319.757 6770524.152)  NaN  ЕИРЦ  NaN  ...     NaN      NaN
# 1  POINT (344464.798 6770860.028)  NaN   NaN  NaN  ...     NaN      NaN
# 2  POINT (344371.445 6770860.291)  NaN   NaN  NaN  ...     NaN      NaN
# 3  POINT (344324.321 6770847.746)  NaN   NaN  NaN  ...     NaN      NaN
# 4  POINT (344298.498 6770844.456)  NaN   NaN  NaN  ...     NaN      NaN
#
#   internet_access:fee outdoor_seating addr:town power_supply ways type  \
# 0                 NaN             NaN       NaN          NaN  NaN  NaN
# 1                 NaN             NaN       NaN          NaN  NaN  NaN
# 2                 NaN             NaN       NaN          NaN  NaN  NaN
# 3                 NaN             NaN       NaN          NaN  NaN  NaN
# 4                 NaN             NaN       NaN          NaN  NaN  NaN
#
#   wikidata wikipedia
# 0      NaN       NaN
# 1      NaN       NaN
# 2      NaN       NaN
# 3      NaN       NaN
# 4      NaN       NaN
#
# [5 rows x 113 columns]

# %%
from blocksnet import BlocksSplitter

bsp = BlocksSplitter(blocks, buildings)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
local_crs = boundaries.estimate_utm_crs()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
blocks = blocks.to_crs(local_crs)
buildings = buildings.to_crs(local_crs)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
if buildings.geometry.isnull().any():
    print("Есть пустые значения в геометрии.")
    buildings = blocks[blocks.geometry.notnull()]  # Удаляем пустые значения

# %%
splitted_blocks = bsp.run()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2024-12-24 12:42:00.982 | INFO     | blocksnet.preprocessing.blocks_splitter:run:167 - Joining buildings and blocks to exclude duplicates
# 2024-12-24 12:42:01.091 | INFO     | blocksnet.preprocessing.blocks_splitter:run:176 - Choosing blocks to be splitted
# 2024-12-24 12:42:01.187 | INFO     | blocksnet.preprocessing.blocks_splitter:run:185 - Splitting filtered blocks
#   0%|          | 0/3 [00:00<?, ?it/s]Exception ignored on calling ctypes callback function: <function ThreadpoolController._find_libraries_with_dl_iterate_phdr.<locals>.match_library_callback at 0x7ca0d831d630>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/threadpoolctl.py", line 1005, in match_library_callback
#     self._make_controller_from_path(filepath)
#   File "/usr/local/lib/python3.10/dist-packages/threadpoolctl.py", line 1175, in _make_controller_from_path
#     lib_controller = controller_class(
#   File "/usr/local/lib/python3.10/dist-packages/threadpoolctl.py", line 114, in __init__
#     self.dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
#   File "/usr/lib/python3.10/ctypes/__init__.py", line 374, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: /usr/local/lib/python3.10/dist-packages/numpy.libs/libopenblas64_p-r0-0cf96a72.3.23.dev.so: cannot open shared object file: No such file or directory
# 100%|██████████| 3/3 [00:06<00:00,  2.14s/it]

# %%
len(blocks), len(splitted_blocks)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (247, 258)

# %%
blocks.plot(linewidth=0.1, figsize=(10,10)).set_axis_off()
splitted_blocks.plot(linewidth=0.1, figsize=(10,10)).set_axis_off()

# %%
splitted_blocks.to_file('blocks.geojson')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
